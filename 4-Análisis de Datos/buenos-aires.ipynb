# %% [markdown]
# # **Exploración**
#
# Vamos a analizar datos de una fuente real. Los ingresos de los funcionarios son información pública que se libera anualmente en el <a href='https://data.buenosaires.gob.ar/dataset/sueldo-funcionarios'>portal de datos abiertos</a> de GCBA.
#
# En general los 4 primeros pasos para analizar un data set son:
# 1. Leerlo
# 2. Consultar cuáles son las columnas
# 3. Extraer una muestra
# 4. Verificar cuántos registros tiene

# %% [markdown]
# ## **Lectura de Data Set**
#
# Con la función `pd.read_csv()` podemos leer archivos que estén en una url pública o en una ubicación del disco accesible desde la Jupyter Notebook.

# %%
import pandas as pd
import numpy as np
import time

df = pd.read_csv('http://cdn.buenosaires.gob.ar/datosabiertos/datasets/sueldo-funcionarios/sueldo_funcionarios_2019.csv')
df
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 0    20-17692128-6  2019    1    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 1    20-17735449-0  2019    1             SANTILLI        DIEGO CESAR
# 2    27-24483014-0  2019    1                ACUÑA      MARIA SOLEDAD
# 3    20-13872301-2  2019    1             ASTARLOA      GABRIEL MARIA
# 4    20-25641207-2  2019    1             AVOGADRO       ENRIQUE LUIS
# ..             ...   ...  ...                  ...                ...
# 380  20-26735689-1  2019   12               MENDEZ          JUAN JOSE
# 381  20-23864572-8  2019   12             STRAFACE     FERNANDO DIEGO
# 382  20-21981279-6  2019   12        SCRENCI SILVA        BRUNO GUIDO
# 383  20-30593774-7  2019   12           AVELLANEDA   PATRICIO IGNACIO
# 384  27-27011181-0  2019   12            FERNANDEZ     KARINA BEATRIZ
#
#                                            reparticion  \
# 0                                     Jefe de Gobierno
# 1                             Vicejefatura de Gobierno
# 2                 Ministerio de Educación e Innovación
# 3     Procuración General de la Ciudad de Buenos Aires
# 4                                Ministerio de Cultura
# ..                                                 ...
# 380                   SECR Transporte y Obras Públicas
# 381          SECR General y Relaciones Internacionales
# 382                             Ministerio de Gobierno
# 383  SECR Planificación, Evaluación y Coordinación ...
# 384                          SECR Asuntos Estratégicos
#
#      asignacion_por_cargo_i  aguinaldo_ii  total_salario_bruto_i_+_ii  \
# 0                 197745.80          0.00                   197745.80
# 1                 197745.80          0.00                   197745.80
# 2                 224516.62          0.00                   224516.62
# 3                 224516.62          0.00                   224516.62
# 4                 224516.62          0.00                   224516.62
# ..                      ...           ...                         ...
# 380               249972.86     124986.43                   374959.29
# 381               275089.75     137544.87                   412634.62
# 382               275089.75     137544.87                   412634.62
# 383               249972.86     124986.43                   374959.29
# 384               187539.45      15628.29                   203167.74
#
#            observaciones
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 380                  NaN
# 381                  NaN
# 382                  NaN
# 383                  NaN
# 384  alta desde el 10/12
#
# [385 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['cuil', 'anio', 'mes', 'funcionario_apellido', 'funcionario_nombre',
#        'reparticion', 'asignacion_por_cargo_i', 'aguinaldo_ii',
#        'total_salario_bruto_i_+_ii', 'observaciones'],
#       dtype='object')

# %%
df.sample(5)  #Selecciona una muestra de registros aletoria
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 364  20-29751476-9  2019   12             CARRILLO            FACUNDO
# 83   20-24424714-9  2019    3         D'ALESSANDRO     MARCELO SILVIO
# 39   20-17110752-1  2019    2         MACCHIAVELLI    EDUARDO ALBERTO
# 183  20-16891539-0  2019    6              ROBREDO            GONZALO
# 179  20-20008464-1  2019    6               GIUSTI          JOSE LUIS
#
#                                            reparticion  \
# 364          SECR Atención Ciudadana y Gestión Comunal
# 83                           SECR Justicia y Seguridad
# 39            Ministerio de Ambiente y Espacio Público
# 183                        Ente de Turismo Ley Nº 2627
# 179  UPE Transferencia de Funciones y Facultades en...
#
#      asignacion_por_cargo_i  aguinaldo_ii  total_salario_bruto_i_+_ii  \
# 364               249972.86     124986.43                   374959.29
# 83                210061.14          0.00                   210061.14
# 39                224516.62          0.00                   224516.62
# 183               226866.41     113433.21                   340299.62
# 179               226866.41     113433.21                   340299.62
#
#     observaciones
# 364           NaN
# 83            NaN
# 39            NaN
# 183           NaN
# 179           NaN

# %%
# La propiedad shape nos devuelve una tupla (filas,columnas)
df.shape
# Out:
# (385, 10)

# %% [markdown]
# # **Vectorización con Pandas**
#
# Pandas es una de las librerías de Python más usadas para análisis de datos. El nombre pandas viene de "Panel Data Analysis" y su funcionalidad permite hacer operaciones sobre datos que se encuentran en memoria de manera eficiente.
#
# Pandas es útil para trabajar sobre datos tabulares, con dos condiciones importantes:
#
# I. Los datos se encuentran enteramente en la memoria RAM. Con lo cual, el tamaño de los datos que podemos manipular está limitado por el hardware. Como regla de pulgar, es una buena práctica no ocupar más de 1/3 de la memoria RAM de nuestro dispositivo con el dataset. Así, si estamos trabajando localmente en una notebook con 8GB de memoria RAM no es recomendable procesar datasets de más de 2.33GB.
#
# II. En pandas, las operaciones sobre filas y columnas son, en general, eficientes porque se hacen de forma "vectorizada". En realidad esta optimización, se hace desde numpy, una librería para realizar operaciones matemáticas que se utilizó a su vez para escribir pandas.
#
# Las operaciones vectorizadas son las que se realizan en bloque en vez de caso por caso. Las computadoras de hoy tienen la capacidad de recibir muchas instrucciones juntas y procesar varias de ellas a la vez.
#
# Es importante entender que Pandas trabaja de esta manera y que por eso es una de las herramientas más elegidas para manipular datos en memoria.

# %%
#Ejemplo de Vectorización (Muchos datos al mismo tiempo)
#para saber cuando se demora el calculo
# %timeit
df["bonificacion"]=df["asignacion_por_cargo_i"]*0.
df.head()
# Out:
#             cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 0  20-17692128-6  2019    1    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 1  20-17735449-0  2019    1             SANTILLI        DIEGO CESAR
# 2  27-24483014-0  2019    1                ACUÑA      MARIA SOLEDAD
# 3  20-13872301-2  2019    1             ASTARLOA      GABRIEL MARIA
# 4  20-25641207-2  2019    1             AVOGADRO       ENRIQUE LUIS
#
#                                         reparticion  asignacion_por_cargo_i  \
# 0                                  Jefe de Gobierno               197745.80
# 1                          Vicejefatura de Gobierno               197745.80
# 2              Ministerio de Educación e Innovación               224516.62
# 3  Procuración General de la Ciudad de Buenos Aires               224516.62
# 4                             Ministerio de Cultura               224516.62
#
#    aguinaldo_ii  total_salario_bruto_i_+_ii observaciones  bonificacion
# 0           0.0                   197745.80           NaN           0.0
# 1           0.0                   197745.80           NaN           0.0
# 2           0.0                   224516.62           NaN           0.0
# 3           0.0                   224516.62           NaN           0.0
# 4           0.0                   224516.62           NaN           0.0

# %% [markdown]
# # **Objetos fundamentales de Pandas**

# %% [markdown]
# ## **Series**
#
# Las series son "columnas" que de una tabla que están asociadas a un índice y a un nombre. Igual que una lista común de Python es una secuencia de elementos ordenados, pero a diferencia de la lista está asociada a más información.

# %%
# Las series se pueden crear a partir de una lista
serie = pd.Series(['a','b','c'])

# %%
# Propiedades importantes de las series
print('Tipo de objetos que tiene ', serie.dtype)
print('Nombre ', serie.name)
print('Index ',serie.index)
print('Valores ',serie.values)
# Out:
# Tipo de objetos que tiene  object
# Nombre  None
# Index  RangeIndex(start=0, stop=3, step=1)
# Valores  ['a' 'b' 'c']

# %% [markdown]
# ## **DataFrames**
#
# Los DataFrames son "tablas", compuestas por varias "columnas" o series que comparten todas un mismo índice. En general los DataFrames se crean a partir de leer tablas de archivos (pueden ser en formato json o csv) pero a veces también se crean a partir de listas de diccionarios o de otras maneras.
#
# Los DataFrames tienen un objeto Index que describe los nombres de columnas y otro objeto Index que describen los nombres de las filas.

# %%
# Leemos un dataset público
df = pd.read_csv('http://cdn.buenosaires.gob.ar/datosabiertos/datasets/sueldo-funcionarios/sueldo_funcionarios_2019.csv')

# %%
# Propiedades importantes de los dataframes
print('Columnas ', df.columns)
print('Index ', df.index)
print('Dimensiones ',df.shape)
# Out:
# Columnas  Index(['cuil', 'anio', 'mes', 'funcionario_apellido', 'funcionario_nombre',
#        'reparticion', 'asignacion_por_cargo_i', 'aguinaldo_ii',
#        'total_salario_bruto_i_+_ii', 'observaciones'],
#       dtype='object')
# Index  RangeIndex(start=0, stop=385, step=1)
# Dimensiones  (385, 10)

# %%
# Consultar las primeras filas
df.head()
# Out:
#             cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 0  20-17692128-6  2019    1    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 1  20-17735449-0  2019    1             SANTILLI        DIEGO CESAR
# 2  27-24483014-0  2019    1                ACUÑA      MARIA SOLEDAD
# 3  20-13872301-2  2019    1             ASTARLOA      GABRIEL MARIA
# 4  20-25641207-2  2019    1             AVOGADRO       ENRIQUE LUIS
#
#                                         reparticion  asignacion_por_cargo_i  \
# 0                                  Jefe de Gobierno               197745.80
# 1                          Vicejefatura de Gobierno               197745.80
# 2              Ministerio de Educación e Innovación               224516.62
# 3  Procuración General de la Ciudad de Buenos Aires               224516.62
# 4                             Ministerio de Cultura               224516.62
#
#    aguinaldo_ii  total_salario_bruto_i_+_ii observaciones
# 0           0.0                   197745.80           NaN
# 1           0.0                   197745.80           NaN
# 2           0.0                   224516.62           NaN
# 3           0.0                   224516.62           NaN
# 4           0.0                   224516.62           NaN

# %% [markdown]
# Si queremos extraer una serie del DataFrame, podemos hacerlo de la misma forma en que extraemos un valor de un diccionario.

# %%
serie_mes = df['mes']

# %%
type(serie_mes) #tipo de dato que se esta
serie_mes
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 380    12
# 381    12
# 382    12
# 383    12
# 384    12
# Name: mes, Length: 385, dtype: int64

# %% [markdown]
# ## **Índices**
#
# Los índices acompañan a las series y a los Data Frames. Son conjuntos ordenados e inmutables de elementos

# %%
df.index
# Out:
# RangeIndex(start=0, stop=385, step=1)

# %%
df.columns
# Out:
# Index(['cuil', 'anio', 'mes', 'funcionario_apellido', 'funcionario_nombre',
#        'reparticion', 'asignacion_por_cargo_i', 'aguinaldo_ii',
#        'total_salario_bruto_i_+_ii', 'observaciones'],
#       dtype='object')

# %%
ind = pd.Index([2, 3, 5, 7, 11])
ind
# Out:
# Index([2, 3, 5, 7, 11], dtype='int64')

# %% [markdown]
# ### **Ejercicio**
# Exploren el dataset público que se encuentra en la siguiente url: https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv ¿De qué se trata? ¿Cuántas filas tiene? ¿Cuántas columnas? Al leerlo, pueden almacenarlo en la variable df_titanic.

# %%
df_titanic = pd.read_csv('https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv',sep=",")

# %%
df_titanic.describe()
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# max                   6.000000  512.32920

# %%
df_titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
df_titanic.shape
# Out:
# (887, 8)

# %% [markdown]
# ## **Filtrando un DataFrame (Indexing)**
#
# Hay muchas técnicas para filtrar un DataFrame. Podemos querer filtrar por columnas o por filas, por posición o por nombre. También podemos querer filtrar por condiciones que se cumplen o no. Cuando no queremos filtrar sobre una dimensión (filas o columnas) usamos ":" para seleccionar todo.

# %% [markdown]
# ### **Boolean Indexing**
#
# Supongamos que queremos tomar el dataset de funcionarios y quedarnos únicamente con los que pertenecen al Ministerio de Cultura.
# Para eso lo que hacemos es indexar al DataFrame por una condición booleana. Eso implica que debemos crear una serie compuesta por valores True y False para aplicarla como índice a las filas.
#
# Los operadores que sirven para evaluar condiciones sobre las series son:
#
#
# | S  | Descripción   | S  | Descripción   |   |
# |----|---------------|----|---------------|---|
# | >= | Mayor o Igual | <= | Menor o Igual |   |
# | == | Igual         | != | Distinto      |   |
# | >  | Mayor         | <  | Menor         |   |

# %% [markdown]
# ### **Máscara booleana**
#
# Veamos lo que pasa cuando le aplicamos a una serie una condición que devuelve un booleano

# %%
mascara_booleana = df['anio'] != 2019
mascara_booleana
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 380    False
# 381    False
# 382    False
# 383    False
# 384    False
# Name: anio, Length: 385, dtype: bool

# %% [markdown]
# Nos devuelve una serie de la misma longitud que la original y que contiene sólo valores True o False.

# %%
type(mascara_booleana)
# Out:
# pandas.core.series.Series

# %%
mascara_booleana.shape
# Out:
# (385,)

# %%
mascara_booleana.dtype
# Out:
# dtype('bool')

# %% [markdown]
# Ahora seleccionemos entonces, los registros que corresponden al Ministerio de Cultura.

# %%
df_min_cul = df.loc[df['reparticion'] == 'Ministerio de Cultura',:]
df_min_cul.head()
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 4    20-25641207-2  2019    1             AVOGADRO       ENRIQUE LUIS
# 36   20-25641207-2  2019    2             AVOGADRO       ENRIQUE LUIS
# 68   20-25641207-2  2019    3             AVOGADRO       ENRIQUE LUIS
# 99   20-25641207-2  2019    4             AVOGADRO       ENRIQUE LUIS
# 130  20-25641207-2  2019    5             AVOGADRO       ENRIQUE LUIS
#
#                reparticion  asignacion_por_cargo_i  aguinaldo_ii  \
# 4    Ministerio de Cultura               224516.62           0.0
# 36   Ministerio de Cultura               224516.62           0.0
# 68   Ministerio de Cultura               231167.76           0.0
# 99   Ministerio de Cultura               249661.60           0.0
# 130  Ministerio de Cultura               249661.60           0.0
#
#      total_salario_bruto_i_+_ii observaciones
# 4                     224516.62           NaN
# 36                    224516.62           NaN
# 68                    231167.76           NaN
# 99                    249661.60           NaN
# 130                   249661.60           NaN

# %%
# Veamos la cantidad de casos
df_min_cul.shape
# Out:
# (12, 10)

# %% [markdown]
# ### **Ejercicio**
#
# Traer todos los sueldos de la segunda mitad del año...

# %%
df_mitaddos = df[df['mes'] >=7]
df_mitaddos
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 188  20-17692128-6  2019    7    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 189  20-17735449-0  2019    7             SANTILLI        DIEGO CESAR
# 190  27-24483014-0  2019    7                ACUÑA      MARIA SOLEDAD
# 191  20-13872301-2  2019    7             ASTARLOA      GABRIEL MARIA
# 192  20-25641207-2  2019    7             AVOGADRO       ENRIQUE LUIS
# ..             ...   ...  ...                  ...                ...
# 380  20-26735689-1  2019   12               MENDEZ          JUAN JOSE
# 381  20-23864572-8  2019   12             STRAFACE     FERNANDO DIEGO
# 382  20-21981279-6  2019   12        SCRENCI SILVA        BRUNO GUIDO
# 383  20-30593774-7  2019   12           AVELLANEDA   PATRICIO IGNACIO
# 384  27-27011181-0  2019   12            FERNANDEZ     KARINA BEATRIZ
#
#                                            reparticion  \
# 188                                   Jefe de Gobierno
# 189                           Vicejefatura de Gobierno
# 190               Ministerio de Educación e Innovación
# 191   Procuración General de la Ciudad de Buenos Aires
# 192                              Ministerio de Cultura
# ..                                                 ...
# 380                   SECR Transporte y Obras Públicas
# 381          SECR General y Relaciones Internacionales
# 382                             Ministerio de Gobierno
# 383  SECR Planificación, Evaluación y Coordinación ...
# 384                          SECR Asuntos Estratégicos
#
#      asignacion_por_cargo_i  aguinaldo_ii  total_salario_bruto_i_+_ii  \
# 188               228396.40          0.00                   228396.40
# 189               228396.40          0.00                   228396.40
# 190               263531.98          0.00                   263531.98
# 191               263531.98          0.00                   263531.98
# 192               263531.98          0.00                   263531.98
# ..                      ...           ...                         ...
# 380               249972.86     124986.43                   374959.29
# 381               275089.75     137544.87                   412634.62
# 382               275089.75     137544.87                   412634.62
# 383               249972.86     124986.43                   374959.29
# 384               187539.45      15628.29                   203167.74
#
#            observaciones
# 188                  NaN
# 189                  NaN
# 190                  NaN
# 191                  NaN
# 192                  NaN
# ..                   ...
# 380                  NaN
# 381                  NaN
# 382                  NaN
# 383                  NaN
# 384  alta desde el 10/12
#
# [197 rows x 10 columns]

# %%
df_mitaddos.shape
# Out:
# (197, 10)

# %% [markdown]
# ### **Ejercicio**
# Volviendo al DataFrame del Titanic ¿Cuántos pasajeros sobrevivieron y cuántos no? ¿Cuántos pagaron una tarifa menor a 25?

# %%
df_titanic_sob=df_titanic.loc[df_titanic["Survived"] == 1,:]

# %%
df_titanic_sob.shape
# Out:
# (342, 8)

# %%
df_titanic_nosob=df_titanic.loc[df_titanic["Survived"] == 0,:]

# %%
df_titanic_nosob.shape
# Out:
# (545, 8)

# %% [markdown]
# ### **Máscara booleana con muchas condiciones**
#
# Ahora tratemos de filtrar el dataset por dos condiciones: por ejemplo tomar los sueldos de abril de la secretaria de innovación.
# Para eso tenemos que combinar dos máscaras booleanas con una condición.
#
# | S | Descripcion        | S  | Descripcion |   |
# |---|--------------------|----|-------------|---|
# | & | AND (y)            | \| | OR (o)      |   |
# | ^ | XOR (o exclusivo)  | ~  | NOT (no)    |   |
#
#
#
# Por ejemplo: seleccionemos los casos donde o bien se haya cobrado aguinaldo o bien el salario total haya sido mayor que 240.000, pero no las dos cosas.

# %%
df[(df['total_salario_bruto_i_+_ii'] > 240000) ^ (df['aguinaldo_ii'] > 0)]
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 55   20-26781618-3  2019    2                LARRE       PEDRO ANDRES
# 97   27-24483014-0  2019    4                ACUÑA      MARIA SOLEDAD
# 98   20-13872301-2  2019    4             ASTARLOA      GABRIEL MARIA
# 99   20-25641207-2  2019    4             AVOGADRO       ENRIQUE LUIS
# 100  27-13221055-7  2019    4            BOU PEREZ          ANA MARIA
# ..             ...   ...  ...                  ...                ...
# 360  20-28908968-4  2019   12       COELHO CHICANO          CHRISTIAN
# 361  20-28908968-4  2019   12       COELHO CHICANO          CHRISTIAN
# 362  20-24424714-9  2019   12         D'ALESSANDRO     MARCELO SILVIO
# 363  20-24424714-9  2019   12         D'ALESSANDRO     MARCELO SILVIO
# 384  27-27011181-0  2019   12            FERNANDEZ     KARINA BEATRIZ
#
#                                           reparticion  asignacion_por_cargo_i  \
# 55              SECR Ciencia, Tecnologia e Innovacion               204017.27
# 97               Ministerio de Educación e Innovación               249661.60
# 98   Procuración General de la Ciudad de Buenos Aires               249661.60
# 99                              Ministerio de Cultura               249661.60
# 100                               Ministerio de Salud               249661.60
# ..                                                ...                     ...
# 360                                     SS Contenidos                74991.86
# 361                                    SECR de Medios               187539.45
# 362                         SECR Justicia y Seguridad                74991.86
# 363                         SECR Justicia y Seguridad               187539.45
# 384                         SECR Asuntos Estratégicos               187539.45
#
#      aguinaldo_ii  total_salario_bruto_i_+_ii        observaciones
# 55       34002.88                   238020.15       baja 28/2/2019
# 97           0.00                   249661.60                  NaN
# 98           0.00                   249661.60                  NaN
# 99           0.00                   249661.60                  NaN
# 100          0.00                   249661.60                  NaN
# ..            ...                         ...                  ...
# 360     110404.68                   185396.54         baja al 9/12
# 361      15628.29                   203167.74  alta desde el 10/12
# 362     110404.68                   185396.54         baja al 9/12
# 363      15628.29                   203167.74  alta desde el 10/12
# 384      15628.29                   203167.74  alta desde el 10/12
#
# [170 rows x 10 columns]

# %% [markdown]
# Ahora veamos los sueldos de febrero de la SECR Ciencia, Tecnologia e Innovacion.

# %%
df[(df['mes'] == 2) & (df['reparticion'] == 'SECR Ciencia, Tecnologia e Innovacion')]
# Out:
#              cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 55  20-26781618-3  2019    2                LARRE       PEDRO ANDRES
#
#                               reparticion  asignacion_por_cargo_i  \
# 55  SECR Ciencia, Tecnologia e Innovacion               204017.27
#
#     aguinaldo_ii  total_salario_bruto_i_+_ii   observaciones
# 55      34002.88                   238020.15  baja 28/2/2019

# %% [markdown]
# ## **Boolean indexing con query()**
#
# La sintaxis que se utiliza para hacer Boolean indexing es un poco repetitiva. Noten que filtrar (aún en su expresión más corta sin loc ni especificar filas o columnas) implica ESCRIBIR DOS VECES el nombre del dataset. Para crear un shortcut, Pandas ofrece la función .query()

# %%
df_cult = df.query('reparticion == "Ministerio de Cultura"')

# %% [markdown]
# También se puede hacer query sobre múltiples condiciones.

# %%
df2 = df.query('asignacion_por_cargo_i > 240000 & aguinaldo_ii > 0')

# %%
df2.shape
# Out:
# (34, 10)

# %% [markdown]
# ### **Ejercicio**
# Piensen cómo traducir a la sintaxis de query, estas consultas que ya hicimos

# %%
# df_sem2 = df[df['mes'] > 6]
df_sem2 =df.query('mes > 6')
df_sem2.shape
# Out:
# (197, 10)

# %%
# df[(df['mes'] == 2) & (df['reparticion'] == 'SECR Ciencia, Tecnologia e Innovacion')]
df5= df.query('mes == 2 & reparticion == "SECR Ciencia, Tecnologia e Innovacion"')
df5.shape
# Out:
# (1, 10)

# %% [markdown]
# ## **Fancy Indexing**
#
# Ahora vamos a quedarnos con un subconjunto de columnas del DataFrame.

# %%
df_view = df.loc[:,['anio','mes']]

# %%
df_view.shape
# Out:
# (385, 2)

# %%
df_view
# Out:
#      anio  mes
# 0    2019    1
# 1    2019    1
# 2    2019    1
# 3    2019    1
# 4    2019    1
# ..    ...  ...
# 380  2019   12
# 381  2019   12
# 382  2019   12
# 383  2019   12
# 384  2019   12
#
# [385 rows x 2 columns]

# %% [markdown]
# Existe una forma menos explícita de hacer esta misma operación. Si pasamos una lista al indexing, pandas asume que el tipo de indexing es loc y que el filtro es sobre las columnas y no las filas:

# %%
df_view = df[['anio','mes']]

# %%
df_view.shape
# Out:
# (385, 2)

# %% [markdown]
# Fíjense lo que pasa si tratamos de acceder a filas utilizando una lista de nombres, en este caso [0,1].

# %%
# Incorrecto
df_view = df[[3,8]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 2
#       1 # Incorrecto
# ----> 2 df_view = df[[3,8]]
#
# File ~/Documents/Computational/lib/python3.13/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4115                 indexer = [indexer]
#    4116         else:
#    4117             if is_iterator(key):
#    4118                 key = list(key)
# -> 4119             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4120
#    4121         # take() does not accept boolean indexers
#    4122         if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/Computational/lib/python3.13/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~/Documents/Computational/lib/python3.13/site-packages/pandas/core/indexes/base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([3, 8], dtype='int64')] are in the [columns]"

# %% [markdown]
# Nos da un error porque cuando pasamos únicamente una lista al indexing, pandas asume que queremos un set de columnas y si los nombres no existen, da error. La forma correcta de hacerlo es pasar una lista de índices y explicitar que vamos a indizar con loc y que seleccionamos todas las columnas.

# %%
# Correcto
df_view = df.loc[[3,8],:]

# %%
df_view
# Out:
#             cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 3  20-13872301-2  2019    1             ASTARLOA      GABRIEL MARIA
# 8  20-22293873-3  2019    1               MIGUEL       FELIPE OSCAR
#
#                                         reparticion  asignacion_por_cargo_i  \
# 3  Procuración General de la Ciudad de Buenos Aires               224516.62
# 8                 Jefatura de Gabinete de Ministros               224516.62
#
#    aguinaldo_ii  total_salario_bruto_i_+_ii observaciones
# 3           0.0                   224516.62           NaN
# 8           0.0                   224516.62           NaN

# %% [markdown]
# ## **Ejercicio**
# Para el Data Set de Titanic
#
# 1) ¿Cuántos hombres y mujeres sobrevivieron?
#
# 2) ¿Cuántos menores de 18 años había? ¿Cuántos sobrevivieron?
#
# 3) Seleccionen únicamente las columnas Sex y Survived y almacenenlas en un nuevo DataFrame que se llame df_titanic_subset.

# %%
# Agrupamos por sexo y condición de supervivencia
survivors_by_sex = df_titanic.groupby(["Sex", "Survived"]).size().unstack()
print(survivors_by_sex)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      464  109

# %%
# Filtramos los menores de 18 años
menores = df_titanic[df_titanic["Age"] < 18]

# Total de menores
total_menores = len(menores)

# Menores que sobrevivieron
menores_sobrevivieron = menores["Survived"].sum()  # porque Survived es 0 o 1

print("Total de menores de 18:", total_menores)
print("Menores que sobrevivieron:", menores_sobrevivieron)
# Out:
# Total de menores de 18: 130
# Menores que sobrevivieron: 65

# %%
df_titanic_subset = df_titanic[["Sex", "Survived"]]
print(df_titanic_subset.head())
# Out:
#       Sex  Survived
# 0    male         0
# 1  female         1
# 2  female         1
# 3  female         1
# 4    male         0

# %% [markdown]
# # **Funciones de Agregación**
#
# Utilizando Pandas podemos aplicar funciones a nivel de columna. Algunas funciones predefinidas son la media, el desvío estándar y la sumatoria, el valor máximo y el mínimo.
#
# Algunas de las funciones de agregación más comunes son:
#
# <ul>
#     <li>min</li>
#     <li>max</li>
#     <li>count</li>
#     <li>sum</li>
#     <li>prod</li>
#     <li>mean</li>
#     <li>median</li>
#     <li>mode</li>
#     <li>std</li>
#     <li>var</li>
# </ul>

# %%
df['mes'].max()
# Out:
# np.int64(12)

# %%
df['asignacion_por_cargo_i'].mean()
# Out:
# np.float64(234234.36800000002)

# %%
df['asignacion_por_cargo_i'].std()
# Out:
# np.float64(35043.160084661766)

# %%
df['total_salario_bruto_i_+_ii'].sum()
# Out:
# np.float64(97988834.36000001)

# %% [markdown]
# Podemos combinar los filtros que vimos antes con las funciones de agregación para responder preguntas cómo ¿Cuál fue en gasto en asignaciones de funcionarios para la Secretaría de Medios 2019? ¿Y para la de Justicia y Seguridad?

# %%
df[df['reparticion'] == 'SECR de Medios']['total_salario_bruto_i_+_ii'].sum()
# Out:
# np.float64(3232402.25)

# %%
df[df['reparticion'] == 'SECR Justicia y Seguridad']['total_salario_bruto_i_+_ii'].sum()
# Out:
# np.float64(3029551.7300000004)

# %% [markdown]
# Ahora respondamos algunas preguntas: ¿Quién o quiénes del dataset cobran el salario más alto? ¿Y el más bajo?

# %%
df[df['total_salario_bruto_i_+_ii'] == df['total_salario_bruto_i_+_ii'].max()]
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 374  20-13872301-2  2019   12             ASTARLOA      GABRIEL MARIA
#
#                                           reparticion  asignacion_por_cargo_i  \
# 374  Procuración General de la Ciudad de Buenos Aires               275089.75
#
#      aguinaldo_ii  total_salario_bruto_i_+_ii observaciones
# 374     170855.56                   445945.31           NaN

# %%
df[df['total_salario_bruto_i_+_ii'] == df['total_salario_bruto_i_+_ii'].min()]
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 344  27-30744939-6  2019   12              FERRERO           GENOVEVA
# 348  20-22709722-2  2019   12                LOPEZ             MATIAS
# 354  20-20008464-1  2019   12               GIUSTI          JOSE LUIS
# 358  20-31164337-2  2019   12         DI BENEDETTO           FEDERICO
# 360  20-28908968-4  2019   12       COELHO CHICANO          CHRISTIAN
# 362  20-24424714-9  2019   12         D'ALESSANDRO     MARCELO SILVIO
#
#                                            reparticion  \
# 344     SECR Administración de Seguridad y Emergencias
# 348                          SECR Desarrollo Ciudadano
# 354  UPE Transferencia de Funciones y Facultades en...
# 358                                    SS Comunicacion
# 360                                      SS Contenidos
# 362                          SECR Justicia y Seguridad
#
#      asignacion_por_cargo_i  aguinaldo_ii  total_salario_bruto_i_+_ii  \
# 344                74991.86     110404.68                   185396.54
# 348                74991.86     110404.68                   185396.54
# 354                74991.86     110404.68                   185396.54
# 358                74991.86     110404.68                   185396.54
# 360                74991.86     110404.68                   185396.54
# 362                74991.86     110404.68                   185396.54
#
#     observaciones
# 344  baja al 9/12
# 348  baja al 9/12
# 354  baja al 9/12
# 358  baja al 9/12
# 360  baja al 9/12
# 362  baja al 9/12

# %% [markdown]
# ## **Análisis para variables numéricas**
#
# Pandas viene con algunas funciones built-in para ayudar al análisis descriptivo.

# %%
df.describe()
# Out:
#          anio         mes  asignacion_por_cargo_i   aguinaldo_ii  \
# count   385.0  385.000000              385.000000     385.000000
# mean   2019.0    6.631169           234234.368000   20282.084883
# std       0.0    3.539077            35043.160085   45248.840725
# min    2019.0    1.000000            74991.860000       0.000000
# 25%    2019.0    4.000000           224516.620000       0.000000
# 50%    2019.0    7.000000           239470.360000       0.000000
# 75%    2019.0   10.000000           249972.870000       0.000000
# max    2019.0   12.000000           275089.750000  170855.560000
#
#        total_salario_bruto_i_+_ii
# count                  385.000000
# mean                254516.452883
# std                  51434.987870
# min                 185396.540000
# 25%                 224516.620000
# 50%                 245811.620000
# 75%                 263531.980000
# max                 445945.310000

# %% [markdown]
# ## **Análisis para variables categóricas**

# %%
df['reparticion'].value_counts()
# Out:
# reparticion
# SECR Desarrollo Ciudadano                                         13
# Ministerio de Salud                                               13
# SECR Justicia y Seguridad                                         13
# SECR de Medios                                                    13
# Jefe de Gobierno                                                  12
# SECR Legal y Técnica                                              12
# SS Contenidos                                                     12
# Ente de Turismo Ley Nº 2627                                       12
# Consejo de los Derechos de Niñas, Niños y Adoles - Presidencia    12
# Vicejefatura de Gobierno                                          12
# UPE Transferencia de Funciones y Facultades en Materia de Seg.    12
# SECR Administración de Seguridad y Emergencias                    12
# SECR Integración Social y Urbana                                  12
# SECR Integración Social Para Personas Mayores                     12
# SECR Planificación, Evaluación y Coordinación de Gestión          12
# SS Comunicacion                                                   12
# Ministerio de Gobierno                                            12
# Ministerio de Desarrollo Urbano y Transporte                      12
# Jefatura de Gabinete de Ministros                                 12
# Procuración General de la Ciudad de Buenos Aires                  12
# Sindicatura General de la Ciudad de Buenos Aires                  12
# Ministerio de Cultura                                             12
# SECR Transporte                                                   11
# Ministerio de Educación e Innovación                              11
# SECR Coordinación General                                         11
# SECR Cultura Ciudadana y Función Pública                          11
# SECR General y de Relaciones Internacionales                      11
# Ministerio de Economía y Finanzas                                 11
# Ministerio de Hábitat y Desarrollo Humano                         11
# SECR Atención y Gestión Ciudadana                                 11
# Ministerio de Ambiente y Espacio Público                          11
# Ministerio de Espacio Público e Higiene Urbana                     2
# SECR Ciencia, Tecnologia e Innovacion                              2
# Ministerio de Desarrollo Humano y Hábitat                          2
# SECR Desarrollo Urbano                                             1
# Ministerio de Desarrollo Económico y Producción                    1
# SECR Ambiente                                                      1
# SECR Comunicación, Contenidos y Participación Ciudadana            1
# SECR Atención Ciudadana y Gestión Comunal                          1
# Ministerio de Educación                                            1
# Ministerio de Hacienda y Finanzas                                  1
# SECR Innovación y Transformación Digital                           1
# SECR Transformación Cultural                                       1
# SECR Transporte y Obras Públicas                                   1
# SECR General y Relaciones Internacionales                          1
# SECR Asuntos Estratégicos                                          1
# Name: count, dtype: int64

# %% [markdown]
# ## **Ejercicio**
#
# Volviendo al ejemplo del Titanic:
#
# 1) ¿Cuál era la edad promedio de los pasajeros de cada clase (Pclass)?
#
# 2) ¿Cuál fue la tarifa que pagaron en promedio los hombres? ¿Y las mujeres?
#
# 3) ¿Cuánto pagaron en total los pasajeros de primera clase para subir al Titanic? ¿Y los de tercera?
#
# 4) ¿Cuántos pasajeros había en cada tipo de clase?

# %%
# 1) Edad promedio de los pasajeros por clase (Pclass)
edad_promedio_clase = df_titanic.groupby("Pclass")["Age"].mean()
print("Edad promedio por clase:")
print(edad_promedio_clase)
# Out:
# Edad promedio por clase:
# Pclass
# 1    38.788981
# 2    29.868641
# 3    25.188747
# Name: Age, dtype: float64

# %%
# 2) Tarifa promedio por sexo
tarifa_promedio_sexo = df_titanic.groupby("Sex")["Fare"].mean()
print("\nTarifa promedio por sexo:")
print(tarifa_promedio_sexo)
# Out:
# Tarifa promedio por sexo:
# Sex
# female    44.479818
# male      25.633935
# Name: Fare, dtype: float64

# %%
# 3) Total pagado por pasajeros de 1ra y 3ra clase
total_tarifa_clase = df_titanic.groupby("Pclass")["Fare"].sum()
print("\nTotal pagado por clase:")
print(total_tarifa_clase.loc[[1, 3]])  # solo primera y tercera clase
# Out:
# Total pagado por clase:
# Pclass
# 1    18177.4125
# 3     6675.6535
# Name: Fare, dtype: float64

# %%
# 4) Número de pasajeros en cada clase
pasajeros_por_clase = df_titanic["Pclass"].value_counts().sort_index()
print("\nPasajeros por clase:")
print(pasajeros_por_clase)
# Out:
# Pasajeros por clase:
# Pclass
# 1    216
# 2    184
# 3    487
# Name: count, dtype: int64

# %% [markdown]
# ## **Ordenar por columnas y limitar la cantidad de resultados**

# %% [markdown]
# Otra forma de resolver el problema de encontrar el mayor y el menos es con el método sort_values. Este método puede recibir un valor único (nombre de columna) o una lista (con varias columnas) y un orden asc o desc. Por default el orden es asc.
#
# Si combinamos el ordenamiento con el método head() para limitar la cantidad de resultados, podemos encontrar los N primeros.

# %%
# Recordemos cómo abrir la documentación de un método
df.sort_values
# Out:
# <bound method DataFrame.sort_values of               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 0    20-17692128-6  2019    1    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 1    20-17735449-0  2019    1             SANTILLI        DIEGO CESAR
# 2    27-24483014-0  2019    1                ACUÑA      MARIA SOLEDAD
# 3    20-13872301-2  2019    1             ASTARLOA      GABRIEL MARIA
# 4    20-25641207-2  2019    1             AVOGADRO       ENRIQUE LUIS
# ..             ...   ...  ...                  ...                ...
# 380  20-26735689-1  2019   12               MENDEZ          JUAN JOSE
# 381  20-23864572-8  2019   12             STRAFACE     FERNANDO DIEGO
# 382  20-21981279-6  2019   12        SCRENCI SILVA        BRUNO GUIDO
# 383  20-30593774-7  2019   12           AVELLANEDA   PATRICIO IGNACIO
# 384  27-27011181-0  2019   12            FERNANDEZ     KARINA BEATRIZ
#
#                                            reparticion  \
# 0                                     Jefe de Gobierno
# 1                             Vicejefatura de Gobierno
# 2                 Ministerio de Educación e Innovación
# 3     Procuración General de la Ciudad de Buenos Aires
# 4                                Ministerio de Cultura
# ..                                                 ...
# 380                   SECR Transporte y Obras Públicas
# 381          SECR General y Relaciones Internacionales
# 382                             Ministerio de Gobierno
# 383  SECR Planificación, Evaluación y Coordinación ...
# 384                          SECR Asuntos Estratégicos
#
#      asignacion_por_cargo_i  aguinaldo_ii  total_salario_bruto_i_+_ii  \
# 0                 197745.80          0.00                   197745.80
# 1                 197745.80          0.00                   197745.80
# 2                 224516.62          0.00                   224516.62
# 3                 224516.62          0.00                   224516.62
# 4                 224516.62          0.00                   224516.62
# ..                      ...           ...                         ...
# 380               249972.86     124986.43                   374959.29
# 381               275089.75     137544.87                   412634.62
# 382               275089.75     137544.87                   412634.62
# 383               249972.86     124986.43                   374959.29
# 384               187539.45      15628.29                   203167.74
#
#            observaciones
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 380                  NaN
# 381                  NaN
# 382                  NaN
# 383                  NaN
# 384  alta desde el 10/12
#
# [385 rows x 10 columns]>

# %%
# Calculamos el máximo
df.sort_values('total_salario_bruto_i_+_ii',ascending=False).head(1)
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 374  20-13872301-2  2019   12             ASTARLOA      GABRIEL MARIA
#
#                                           reparticion  asignacion_por_cargo_i  \
# 374  Procuración General de la Ciudad de Buenos Aires               275089.75
#
#      aguinaldo_ii  total_salario_bruto_i_+_ii observaciones
# 374     170855.56                   445945.31           NaN

# %%
# Calculamos el mínimo
df.sort_values('total_salario_bruto_i_+_ii').head(1)
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 344  27-30744939-6  2019   12              FERRERO           GENOVEVA
#
#                                         reparticion  asignacion_por_cargo_i  \
# 344  SECR Administración de Seguridad y Emergencias                74991.86
#
#      aguinaldo_ii  total_salario_bruto_i_+_ii observaciones
# 344     110404.68                   185396.54  baja al 9/12

# %% [markdown]
# # **Anexo: Vectorización**
#
# ¿Por qué es tan importante trabajar con Pandas y no con funciones escritas por nosotros en Python nativo y que procesen los datos dentro de un for loop?
#
# Por un lado está la comodidad. Hay mucha funcionalidad que ya está desarrollada en Pandas. Existen funciones que resuelven muchos de los problemas clásicos de manipular datos: agrupar, sumarizar, sacar estadísticas, filtrar, etc. Pero además hay una razón de performance.
#
# Veamos una demostración de que vectorizar es más eficiente. Vamos a crear dos listas de 1.000.000 de números aleatorios cada una y vamos a tratar de multiplicar elemento por elemento con pandas y sin pandas:

# %%
lista1 = list(np.random.randint(1, 100, 1000000))
lista2 = list(np.random.randint(1, 100, 1000000))

# %%
# %%timeit
for x,y in zip(lista1,lista2):
    x * y
# Out:
# 97.6 ms ± 2.72 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# Ahora probemos hacer lo mismo con dos series de Pandas

# %%
serie1 = pd.Series(lista1)
serie2 = pd.Series(lista2)

# %%
# %%timeit
resultado = serie1 * serie2
print(resultado)
# Out:
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# ...
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 0          960
# 1          979
# 2          884
# 3         4508
# 4          992
#           ...
# 999995    1638
# 999996    2272
# 999997    9207
# 999998     910
# 999999    4200
# Length: 1000000, dtype: int64
# 5.93 ms ± 910 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Conclusión: la operación vectorizada es <strong> más de 70 veces más rápida.</strong>
